# %% [markdown]
# 14-10-20
# Author: Jamie Billington
#
# Example code using BPTeague cytoflow module for anlaysing and plotting flow cytometry experiments.
# Made a couple of modifications to cytoflow defaults for my plots with matplotlib rcParams and some seaborn bits

# %%
from cytoflow import *
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.colors import Colormap
import seaborn as sns
from pylab import rcParams


font = {'family' : 'normal',
'weight' : 'bold',
'size' : 26}
label = {'family' : 'normal',
'weight' : 'bold',
'size' : 10}

SMALL_SIZE = 6
MEDIUM_SIZE = 10
BIGGER_SIZE = 18
matplotlib.rc('font', **font)
#matplotlib.rc('xtick', labelsize=10)
#matplotlib.rc('ytick', labelsize=10)
matplotlib.rc('axes', titlesize=SMALL_SIZE,labelweight="bold",titleweight='bold')
sns.set(style='ticks', font='sans-serif', font_scale=1.5, color_codes=True)

# %% [markdown]
# Read in a flow cytometry experiment of 60 samples. These represent cells transfected with 20 different insulator sequences (some previously described, other are new candidates). Some of the samples were acquired 12 days post transfection and others at 28 days post transfection. The 28 days pt samples have either been treated with DMSO or NaButryate to inhibit histone deacetylases.

# %%
op_0 = ImportOp(
    conditions={
        'Days_pt': 'category',
        'Condition': 'category',
        'Insulator': 'category'
    },
    tubes=[
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'No Insert'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_B8_B08_020.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'U'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_B5_B05_017.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'V'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_B6_B06_018.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'W'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_B7_B07_019.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'Q'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_B1_B01_013.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'R'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_B2_B02_014.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'S'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_B3_B03_015.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'T'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_B4_B04_016.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'M'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A9_A09_009.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'N'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A10_A10_010.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'O'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A11_A11_011.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'P'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A12_A12_012.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'Mouse AT tDNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A5_A05_005.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': '2x pU6-sgRNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A6_A06_006.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'TMEM'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A7_A07_007.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'L'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A8_A08_008.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': '2x cHS4'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_011_A1_A01_001.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'CBIP'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_017_A2_A02_002.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'Drosophila ILB'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A3_A03_003.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': 'DMSO',
                'Insulator': 'ALOXE3'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_A4_A04_004.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': '2x cHS4'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_011_A1_A01_001.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'No Insert'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B10_B10_021.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'W'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B9_B09_020.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'V'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B8_B08_019.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'U'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B6_B06_017.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'T'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B5_B05_016.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'S'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B4_B04_015.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'R'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B3_B03_014.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'Q'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B2_B02_013.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'P'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B1_B01_012.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'O'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A12_A12_011.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'N'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A11_A11_010.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'M'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A10_A10_009.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'L'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A9_A09_008.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'TMEM'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A8_A08_007.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': '2x pU6-sgRNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A7_A07_006.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'Mouse AT tDNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A6_A06_005.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'ALOXE3'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A5_A05_004.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'Drosophila ILB'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A4_A04_003.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '12',
                'Condition': 'DMSO',
                'Insulator': 'CBIP'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A3_A03_002.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'Drosophila ILB'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C3_C03_023.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'V'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_D6_D06_038.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'W'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_D7_D07_039.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'Q'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_D1_D01_033.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'R'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_D2_D02_034.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'S'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_D3_D03_035.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'T'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_D4_D04_036.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'N'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C10_C10_030.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'O'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C11_C11_031.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'P'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C12_C12_032.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'TMEM'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C7_C07_027.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'L'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C8_C08_028.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'M'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C9_C09_029.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'ALOXE3'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C4_C04_024.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'Mouse AT tDNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C5_C05_025.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': '2x pU6-sgRNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C6_C06_026.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': '2x cHS4'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C1_C01_021.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'CBIP'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_C2_C02_022.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'No Insert'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_D8_D08_040.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator']),
        Tube(
            conditions={
                'Days_pt': '28',
                'Condition': '0.5mM NaButryate',
                'Insulator': 'U'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI C11 08_10_20/Specimen_021_D5_D05_037.fcs',
            conditions_list=['Days_pt', 'Condition', 'Insulator'])
    ])

ex_0 = op_0.apply()

# %% [markdown]
# Gating to isolate intact cells

# %%
op_1 = PolygonOp(
    vertices=[(50551.654568126956, 55436.80579363786), (72875.01008422012,
                                                        97467.89686514194),
              (207974.79801278393, 137871.9779596846), (246243.40746894365,
                                                        102348.9267960263),
              (237256.08252090614, 50284.60753325994), (117811.63482440764,
                                                        22896.606254408896),
              (86211.04065227575,
               23167.77458390247), (50551.654568126956,
                                    55436.80579363786), (50551.654568126956,
                                                         55436.80579363786)],
    xchannel='FSC-A',
    name='Intact',
    ychannel='SSC-A')

ex_1 = op_1.apply(ex_0)

# %%
op_1.default_view().plot(ex_0)

# %% [markdown]
# Gating to isolate single cells from the intact population

# %%
op_2 = PolygonOp(
    vertices=[(41266.3221752589, 32427.26415874899), (109307.87184560194,
                                                      82472.86932719225),
              (214359.4694537885,
               132874.6709737027), (259625.60500853552,
                                    139286.20757891252), (258486.83430275574,
                                                          115421.04354840933),
              (130375.12990252825,
               37414.01485168995), (53223.4145859468,
                                    15151.73497248922), (36426.54667569476,
                                                         19960.387426396577),
              (42120.40020459375,
               31892.96944164817), (41266.3221752589,
                                    32783.460636816206), (41266.3221752589,
                                                          32783.460636816206)],
    xchannel='FSC-A',
    name='Singlets',
    ychannel='FSC-H')

ex_2 = op_2.apply(ex_1)

# %%
op_2.default_view().plot(ex_1)

# %% [markdown]
# Gating recombined cells which are relevant to the assay

# %%
op_3 = PolygonOp(
    vertices=[(-449.8309222123466, 61.94655934117185), (428.84169714662005,
                                                        155.88997120576352),
              (72707.45876997578, 163.67717381714448), (154331.43148169605,
                                                        18.024241989350102),
              (35224.50888015888, -28.29321300037534), (-92.63174874007579,
                                                        -29.32799689693746),
              (-466.2176364637626, 61.94655934117185), (-466.2176364637626,
                                                        61.94655934117185)],
    xscale='logicle',
    xchannel='FITC-A',
    yscale='logicle',
    name='Recombined',
    ychannel='PE-Cy5-A')

ex_3 = op_3.apply(ex_2)

# %%
op_3.default_view(subset='(Intact == True) and (Singlets == True)').plot(ex_2)

# %% [markdown]
# Resulting cells are mNeonGreen (FITC-A) positive and mKate (PE-Cy-5-A) negative

# %%
Kde1DView(
    huefacet='Days_pt',
    channel='FITC-A',
    subset=
    '(Condition == "DMSO") and (Insulator == "TMEM" or Insulator == "U" or Insulator == "V" or Insulator == "W" or Insulator == "R" or Insulator == "S" or Insulator == "T" or Insulator == "M" or Insulator == "N" or Insulator == "O" or Insulator == "P" or Insulator == "Q" or Insulator == "No Insert" or Insulator == "L" or Insulator == "2x cHS4" or Insulator == "Mouse AT tDNA" or Insulator == "2x pU6-sgRNA" or Insulator == "CBIP" or Insulator == "ALOXE3" or Insulator == "Drosophila ILB") and (Intact == True) and (Recombined == True) and (Singlets == True)',
    scale='log',
    xfacet='Insulator').plot(
        ex_3,
        col_wrap=3,
        ylabel='Density',
        lim=(7.0, None),
        xlabel='mNeonGreen',
        sns_style='ticks',
        despine= True,
        sns_context='talk')

# %% [markdown]
# The above plot represents the distibution of fluoresence obtained for each insulator sequence, or candidate insulator sequence.
# Kernel density estimates are used to normalise across experiments with different numbers of cells - scaling by density aids with visualing changes to fluorescence

# %%
Kde1DView(
    huefacet='Condition',
    channel='FITC-A',
    subset=
    '(Days_pt == "28") and (Insulator == "TMEM" or Insulator == "U" or Insulator == "V" or Insulator == "W" or Insulator == "R" or Insulator == "S" or Insulator == "T" or Insulator == "M" or Insulator == "N" or Insulator == "O" or Insulator == "P" or Insulator == "Q" or Insulator == "No Insert" or Insulator == "L" or Insulator == "2x cHS4" or Insulator == "Mouse AT tDNA" or Insulator == "2x pU6-sgRNA" or Insulator == "CBIP" or Insulator == "ALOXE3" or Insulator == "Drosophila ILB") and (Intact == True) and (Recombined == True) and (Singlets == True)',
    scale='log',
    xfacet='Insulator').plot(
        ex_3,
        col_wrap=3,
        ylabel='Density',
        lim=(7.0, None),
        xlabel='mNeonGreen',
        sns_style='ticks',
        despine= True,
        sns_context='talk')

# %% [markdown]
# Comparison between untreated and cells maintained in NaButryrate media at 28days (above)

# %%
Kde1DView(
    huefacet='Days_pt',
    channel='FITC-A',
    subset=
    '(Condition == "DMSO") and (Insulator == "TMEM" or Insulator == "U" or Insulator == "V" or Insulator == "W" or Insulator == "R" or Insulator == "S" or Insulator == "T" or Insulator == "M" or Insulator == "N" or Insulator == "O" or Insulator == "P" or Insulator == "Q" or Insulator == "No Insert" or Insulator == "L" or Insulator == "2x cHS4" or Insulator == "Mouse AT tDNA" or Insulator == "2x pU6-sgRNA" or Insulator == "CBIP" or Insulator == "ALOXE3" or Insulator == "Drosophila ILB") and (Intact == True) and (Recombined == True) and (Singlets == True)',
    scale='log',
    xfacet='Insulator').plot(
        ex_3,
        col_wrap=3,
        ylabel='Density',
        lim=(7.0, None),
        xlabel='mNeonGreen',
        sns_style='ticks',
        despine= True,
        sns_context='talk')

# %% [markdown]
# Comparison between untreated cells at time points 12 and 28 days post transfection

# %%
op_4 = ChannelStatisticOp(
    channel='FITC-A',
    function=geom_mean,
    name='Geom mean',
    by=['Days_pt','Condition', 'Insulator'],
    subset='(Intact == True) and (Recombined == True) and (Singlets == True)',
    statistic_name='Geom.Mean')

ex_4 = op_4.apply(ex_3)

# %% [markdown]
# Calculate and plot geometric mean of the data for each condition as a shorthand for the major conclusions from the exeriment

# %%
BarChartView(
    scale='log',
    statistic=('Geom mean', 'Geom.Mean'),
    variable='Insulator',
    yfacet='Days_pt',
    huefacet='Condition').plot(
        ex_4,
        sns_style='ticks',
        #ylabel='Insert',
        xlabel='Geom Mean Fluorescence intenisty (au)',
        sns_context='poster',orientation='horizontal')
