# %%
from cytoflow import *
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib 
from matplotlib.colors import Colormap
import seaborn as sns
font = {'family' : 'normal',
'weight' : 'bold',
'size' : 26}
label = {'family' : 'normal',
'weight' : 'bold',
'size' : 10}
import seaborn
SMALL_SIZE = 6
MEDIUM_SIZE = 10
BIGGER_SIZE = 18
matplotlib.rc('font', **font)
#matplotlib.rc('xtick', labelsize=10)
#matplotlib.rc('ytick', labelsize=10)
matplotlib.rc('axes', titlesize=SMALL_SIZE,labelweight="bold",titleweight='bold')
sns.set(style='ticks', font='sans-serif', font_scale=1.5, palette="Set1")
from pylab import rcParams

# %%
op_0 = ImportOp(
    conditions={
        'Clone': 'category',
        'Panel': 'category',
        'Insulator': 'category'
    },
    tubes=[
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': 'Drosophila ILB '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A4_A04_003.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'No insert'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D10_D10_043.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'A'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D11_D11_044.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': 'B'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D12_D12_045.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'U'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D6_D06_039.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': '(-)'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D7_D07_040.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'V'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D8_D08_041.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'S'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D4_D04_037.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'T'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D5_D05_038.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': 'P'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D1_D01_034.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': 'Q'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D2_D02_035.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'R'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D3_D03_036.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': 'M'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C10_C10_031.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': 'N'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C11_C11_032.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': 'O'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C12_C12_033.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'TMEM '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C8_C08_029.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': 'L'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C9_C09_030.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'ALOXE3 '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C5_C05_026.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'Mouse AT tDNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C6_C06_027.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': '2x pU6 sgRNA '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C7_C07_028.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': '2x cHS4'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C1_C01_023.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': 'CBIP'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C3_C03_024.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9',
                'Insulator': 'Drosophila ILB '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_C4_C04_025.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'W'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B9_B09_020.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'No insert'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B10_B10_021.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': '2x cHS4 copy'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B11_B11_022.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'T'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B5_B05_016.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'U'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B6_B06_017.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': '(-)'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B7_B07_018.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'V'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B8_B08_019.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': 'P'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B1_B01_012.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': 'Q'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B2_B02_013.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'R'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B3_B03_014.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'S'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_B4_B04_015.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': 'L'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A9_A09_008.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': 'M'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A10_A10_009.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': 'N'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A11_A11_010.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': 'O'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A12_A12_011.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'ALOXE3 '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A5_A05_004.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'Mouse AT tDNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A6_A06_005.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': '2x pU6 sgRNA '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A7_A07_006.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11',
                'Insulator': 'TMEM'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A8_A08_007.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': '2x cHS4'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_011_A1_A01_001.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': 'CBIP'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_A3_A03_002.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9',
                'Insulator': 'W'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20/Specimen_021_D9_D09_042.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2 Un',
                'Insulator': '2x pU6 sgRNA '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_022_E7_E07_045.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2 Un',
                'Insulator': 'Mouse AT tDNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_022_E6_E06_044.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2 Un',
                'Insulator': 'ALOXE3 '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_022_E5_E05_043.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2 Un',
                'Insulator': 'Drosophila ILB '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_022_E4_E04_042.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2 Un',
                'Insulator': 'CBIP'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_022_E3_E03_041.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2 Un',
                'Insulator': 'B'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_022_E2_E02_040.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2 Un',
                'Insulator': '2x cHS4'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_022_E1_E01_039.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9 Un',
                'Insulator': '2x pU6 sgRNA '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_D7_D07_038.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9 Un',
                'Insulator': 'Mouse AT tDNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_D6_D06_037.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'F9 Un',
                'Insulator': 'ALOXE3 '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_D5_D05_036.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9 Un',
                'Insulator': 'Drosophila ILB '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_D4_D04_035.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9 Un',
                'Insulator': 'CBIP'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_D3_D03_034.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9 Un',
                'Insulator': 'Utrophin (-)'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_D2_D02_033.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'F9 Un',
                'Insulator': '2x cHS4'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_D1_D01_032.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11 un',
                'Insulator': '2x pU6 sgRNA '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_C7_C07_031.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11 un',
                'Insulator': 'Mouse AT tDNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_C6_C06_030.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'C11 un',
                'Insulator': 'ALOXE3 '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_C5_C05_029.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11 un',
                'Insulator': 'Drosophila ILB '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_C4_C04_028.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11 un',
                'Insulator': 'CBIP'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_C3_C03_027.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11 un',
                'Insulator': 'Utrophin (-)'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_C2_C02_026.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11 un',
                'Insulator': '2x cHS4'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_C1_C01_025.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'Utrophin copy'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B12_B12_024.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': '2x cHS4 copy'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B11_B11_023.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'No insert'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B10_B10_022.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'W'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B9_B09_021.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'V'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B8_B08_020.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': '(-)'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B7_B07_019.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'U'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B6_B06_018.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'T'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B5_B05_017.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'S'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B4_B04_016.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'R'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B3_B03_015.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'Q'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B2_B02_014.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'P'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_B1_B01_013.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'O'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A12_A12_012.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'N'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A11_A11_011.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'M'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A10_A10_010.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'L'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A9_A09_009.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'TMEM'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A8_A08_008.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': '2x pU6 sgRNA '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A7_A07_007.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'Mouse AT tDNA'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A6_A06_006.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '2',
                'Clone': 'D2',
                'Insulator': 'ALOXE3 '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A5_A05_005.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'Drosophila ILB '
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A4_A04_004.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'CBIP'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_021_A3_A03_003.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': 'Utrophin (-)'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_017_A2_A02_002.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'D2',
                'Insulator': '2x cHS4'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - RPMI 27_9_20_002/Specimen_011_A1_A01_001.fcs'
        ),
        Tube(
            conditions_list=['Clone', 'Insulator', 'Panel'],
            conditions={
                'Panel': '1',
                'Clone': 'C11',
                'Insulator': 'HEK293-FT parental'
            },
            file=
            '/Users/jamie/Documents/PhD/FACS Data/96 Well - Flat bottom activator 2_3_20/Specimen_011_A1_A01_001.fcs'
        )
    ])

ex_0 = op_0.apply()

# %%
op_1 = PolygonOp(
    vertices=[(43344.09967039663, 37142.343870225188), (53644.335655713694,
                                                        111697.13504815809),
              (160766.7899030112, 142252.37733419615), (214843.02882592581,
                                                        132474.69980266396),
              (214843.02882592581,
               87252.941219327622), (169006.97869126487,
                                     29401.682491095547), (105145.51558229903,
                                                           18401.795268121838),
              (43859.111469662479, 37142.343870225188), (43859.111469662479,
                                                         37142.343870225188)],
    ychannel='SSC-A',
    name='Intact',
    xchannel='FSC-A')

ex_1 = op_1.apply(ex_0)

# %%
op_1.default_view().plot(ex_0)

# %%
op_2 = PolygonOp(
    vertices=[(58722.637927682692, 26431.305990611108), (163963.50026365538,
                                                         62668.845457189149),
              (254739.97867667445,
               110985.56474595985), (259727.69727079637,
                                     136754.4816999709), (216334.54550193562,
                                                          139707.17010095133),
              (81666.14346064355,
               86558.778883303559), (42263.16656708032,
                                     54884.485127331645), (38771.763551194977,
                                                           37973.633376261889),
              (57725.094208858296, 25626.027335798266), (57725.094208858296,
                                                         25626.027335798266)],
    ychannel='FSC-H',
    name='Singelt',
    xchannel='FSC-A')

ex_2 = op_2.apply(ex_1)

# %%
op_2.default_view().plot(ex_1)

# %%
op_3 = PolygonOp(
    vertices=[(56.16392770860358,
               61.088836597701388), (706.80258614164552,
                                     685.32603342702453), (81854.787252784736,
                                                           685.32603342702453),
              (89149.182427815394, 9.9085584749526561), (45033.024896516879,
                                                         0.39454508986154768),
              (43.474803710468692, 0.50826461175265392), (6.4605232852017975,
                                                          7.5165380862556699),
              (57.78501520358126, 59.698369511389537), (57.78501520358126,
                                                        59.698369511389537)],
    ychannel='PE-Cy5-A',
    xscale='log',
    yscale='log',
    name='Recombinase',
    xchannel='FITC-A')

ex_3 = op_3.apply(ex_2)

# %%
op_3.default_view(subset='(Intact == True) and (Singelt == True)').plot(ex_2)

# %%
Kde1DView(
    huescale='log',
    subset=
    '(Clone == "C11" or Clone == "F9") and (Insulator == "2x cHS4"  or Insulator == "ALOXE3 " or Insulator == "2x pU6 sgRNA "   or Insulator == "No insert" or Insulator == "Mouse AT tDNA" or Insulator == "TMEM" or Insulator == "CBIP" or Insulator == "Drosophila ILB ") and (Intact == True) and (Recombinase == True) and (Singelt == True)',
    channel='FITC-A',
    scale='log',
    xfacet='Panel',
    huefacet='Insulator',
    yfacet='Clone').plot(
        ex_3,
        sns_context='poster',
        huelabel='Sequence',
        lim=(20.0, None),
        despine =True,
        xlabel='mNeonGreen',
        #col_wrap=2,
        sns_style='ticks',alpha=0.2,linewidth=1.5,
        ylabel='Density',legend=True)

#plt.savefig('D378_insulator_plot.png',dpi=600)
#plt.savefig('D378_insulator_plot_legend.svg',dpi=600)

# %%
Kde1DView(
    huescale='log',
    subset=
    '(Clone == "C11" or Clone == "F9") and (Insulator == "N" or Insulator == "O" or Insulator == "P" or Insulator == "R" or Insulator == "Q" or Insulator == "S" or Insulator == "T" or Insulator == "U" or Insulator == "V" or Insulator == "L" or Insulator == "M" or Insulator == "W") and (Intact == True) and (Recombinase == True) and (Singelt == True)',
    channel='FITC-A',
    scale='log',
    xfacet='Panel',
    huefacet='Insulator',
    yfacet='Clone').plot(
        ex_3,
        sns_context='poster',
        huelabel='Sequence',
        lim=(20.0, None),
        despine =True,
        xlabel='mNeonGreen',
        #col_wrap=2,
        sns_style='ticks',alpha=0.2,linewidth=1.5,
        ylabel='Density',legend=True)

#plt.savefig('D378_insulator_plot.png',dpi=600)
#plt.savefig('D378_insulator_plot_legend.svg',dpi=600)

# %%
# Out:
# ---------------------------------------------------------------------------
# CytoflowViewError                         Traceback (most recent call last)
# <ipython-input-52-f9a536823316> in <module>()
#      11         orientation='horizontal',
#      12         sns_context='poster',
# ---> 13         ylabel='Insulator')
#
# ~/anaconda3/envs/cf/lib/python3.5/site-packages/cytoflow-0.9.2+0.gfb562ea.dirty-py3.5-macosx-10.6-x86_64.egg/cytoflow/views/bar_chart.py in plot(self, experiment, plot_name, **kwargs)
#     129         """
#     130
# --> 131         super().plot(experiment, plot_name, **kwargs)
#     132
#     133     def _grid_plot(self, experiment, grid, **kwargs):
#
# ~/anaconda3/envs/cf/lib/python3.5/site-packages/cytoflow-0.9.2+0.gfb562ea.dirty-py3.5-macosx-10.6-x86_64.egg/cytoflow/views/base_views.py in plot(self, experiment, plot_name, **kwargs)
#     818                                          "No experiment specified")
#     819
# ...

# %%
DensityView(
    xfacet='Insulator',
    yscale='log',
    xscale='log',
    ychannel='PE-Cy5-A',
    subset='(Clone == "F9") and (Insulator == "2x cHS4" or Insulator == "2x pU6 sgRNA " or Insulator == "ALOXE3 " or Insulator == "No insert" or Insulator == "Mouse AT tDNA " or Insulator == "TMEM" or Insulator == "CBIP" or Insulator == "Drosophila ILB ") and (Intact == True) and (Recombinase == True) and (Singelt == True)',
    huescale='log',
    xchannel='FITC-A').plot(
        ex_3, legend=False, gridsize=100, sns_style='ticks',xlabel='mNeonGreen',ylabel='mKate',col_wrap=3,xlim=(20,50000),ylim=(5,20000))
#plt.savefig('20-09-20 F9 Insulator_D378_RMPI_log_log_plot.png',dpi=600)
#plt.savefig('15-09-20D277_B42_subclones_D378_RMPI_log_log_plot.png',dpi=600)

# %%
op_4 = ChannelStatisticOp(
    function=geom_mean,
    statistic_name='Geom.Mean',
    name='Geom mean',
    by=['Clone', 'Insulator'],
    subset='(Intact == True) and (Recombinase == True) and (Singelt == True)',
    channel='FITC-A')

ex_4 = op_4.apply(ex_3)

# %%
BarChartView(
    subset=
    '(Clone == "C11" or Clone == "F9") and (Insulator == "2x cHS4" or Insulator == "2x pU6 sgRNA "  or Insulator == "ALOXE3 " or Insulator == "No insert" or Insulator == "Mouse AT tDNA" or Insulator == "TMEM" or Insulator == "CBIP" or Insulator == "Drosophila ILB ")',
    scale='log',
    huefacet='Clone',
    variable='Insulator',
    statistic=('Geom mean', 'Geom.Mean')).plot(
        ex_4,
        xlabel=' ',
        sns_style='ticks',
        orientation='vertical',
        sns_context='poster',
        despine= True,
        ylabel='mNeonGreen (Geom Mean Intensity) ')

plt.savefig('06-10-D378_RMPI_geom_means.svg',dpi=600)

# %%
BarChartView(
    subset=
    '(Clone == "C11" or Clone == "F9") and (Insulator == "2x cHS4" or Insulator == "No insert" or Insulator == "2x pU6 sgRNA casette" or Insulator == "ALOXE3 element" or Insulator == "Cyclin B Interacting protein element " or Insulator == "Drosophila ILB element" or Insulator == "Entry" or Insulator == "TMEM element" or Insulator == "Mouse tDNA AT " or Insulator == "N" or Insulator == "O" or Insulator == "P" or Insulator == "R" or Insulator == "Q" or Insulator == "S" or Insulator == "T" or Insulator == "U" or Insulator == "V" or Insulator == "L" or Insulator == "M" or Insulator == "W")',
    scale='log',
    huefacet='Clone',
    variable='Insulator',
    statistic=('Geom mean', 'Geom.Mean')).plot(
        ex_4,
        xlabel='',
        sns_style='ticks',
        orientation='horizontal',
        sns_context='poster',
        ylabel='mNeonGreen (Geom Mean Intensity) ',
despine=True)

plt.savefig('06-10-D378_RMPI_L-W-geom_means.svg',dpi=600)

# %%
df=ex_4.data
subset=df.loc[(df['Intact'] == True) & (df['Singelt'] == True) & (df['Recombinase'] == True)]

subsubset = subset[['FITC-A','Insulator','Clone']]
subsubset
subsubset.to_csv('/Users/jamie/Documents/PhD/Spreadsheets/triple_clone_median_caluclations.csv')

# %%
Kde1DView(
    huescale='log',
    subset=
    '(Clone == "C11" or Clone == "F9") and (Insulator == "2x cHS4" or Insulator == "L" or Insulator == "M"  or Insulator == "O" or Insulator == "P" or Insulator == "N"  or Insulator == "No insert") and (Intact == True) and (Recombinase == True) and (Singelt == True)',
    channel='FITC-A',
    scale='log',
    huefacet='Insulator',
    xfacet='Clone').plot(
        ex_3,
        sns_context='poster',
        huelabel='Sequence',
        lim=(20.0, None),
        despine =True,
        xlabel='mNeonGreen',
        sns_style='ticks',alpha=0.2,linewidth=1.5,
        ylabel='Density',legend=True)

#plt.savefig('D378_insulator L-M_plot.png',dpi=600)
plt.savefig('D378_L-P_plot_legend.svg',dpi=600)

# %%
Kde1DView(
    huescale='log',
    subset=
    '(Clone == "C11 un" or Clone == "F9 Un") and (Insulator == "2x cHS4" or  Insulator == "Drosophila ILB " or Insulator == "Utrophin (-)") and (Intact == True) and (Recombinase == True) and (Singelt == True)',
    channel='FITC-A',
    scale='log',
    huefacet='Insulator',
    xfacet='Clone').plot(
        ex_3,
        sns_context='poster',
        huelabel='Sequence',
        lim=(20.0, None),
        despine =True,
        xlabel='mNeonGreen',
        sns_style='ticks',alpha=0.2,linewidth=1.5,
        ylabel='Density',legend=True)

plt.savefig('D378_uselectec insulator_plot.png',dpi=600)
#plt.savefig('D378_insulator_plot_legend.svg',dpi=600)

# %%
Kde1DView(
    huescale='log',
    subset=
    '(Clone == "C11" or Clone == "F9") and ( Insulator == "T"  or Insulator == "R"  or Insulator == "S" or Insulator == "Q" or Insulator == "W" or Insulator == "U" or Insulator == "V") and (Intact == True) and (Recombinase == True) and (Singelt == True)',
    channel='FITC-A',
    scale='log',
    huefacet='Insulator',
    xfacet='Clone').plot(
        ex_3,
        sns_context='poster',
        huelabel='Sequence',
        col_wrap=2,
        lim=(20.0, None),
        despine =True,
        xlabel='mNeonGreen',
        sns_style='ticks',alpha=0.2,linewidth=1.5,
        ylabel='Density',legend=True)

#plt.savefig('D378_P-Q-insulator_plot.png',dpi=600)
plt.savefig('D378_Q-W_plot_legend.svg',dpi=600)
